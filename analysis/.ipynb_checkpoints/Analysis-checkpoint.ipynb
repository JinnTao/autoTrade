# %%
#import
import pandas as pd
import numpy as np
import datetime as dt
import statsmodels.api as sm

# %% [markdown]
# ## Prepare Data

# %%
import pymongo
host='47.103.52.183'
port=27017
username="test"
password="123123"
role = "admin"
mongo_uri = "mongodb://%s:%s@%s:%s/%s" % (username, password, host, port, role)
conn = pymongo.MongoClient(mongo_uri)
db = conn['futureData']

# %%
def read_mongo(db,collection, query={},projection={},no_id=True,limit = 10):
    """ Read from Mongo and Store into DataFrame. """

    #return db[collection]
    cursor = db[collection].find(filter=query,projection= projection).limit(limit)
    
    # Expand the cursor and construct the DataFrame
    df = pd.DataFrame(list(cursor))
    #df.to_csv("abc.csv", encoding="utf_8_sig")  # 处理中文乱码问题

    if no_id:
        del df['_id']

    return df
def standard_data(df):
    
    return df.set_index('recordTime').resample('500ms').last().ffill().sort_index(ascending=False)

# %%
projection = {
              'InstrumentID':1,'TradingDay':1,'UpdateTime':1,
              'recordTime':1,'BidPrice1':1,'BidVolume1':1,
              'AskPrice1':1,'AskVolume1':1,'LastPrice':1
             }
read_mongo(db,collection='i1909',query={},projection=)
# Out:
# Database(MongoClient(host=['47.103.52.183:27017'], document_class=dict, tz_aware=False, connect=True), u'futureData')

# %%
dblist = myclient.list_database_names()
# dblist = myclient.database_names() 
if "runoobdb" in dblist:
  print("数据库已存在！")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-2-b4d1030d2793> in <module>()
#       3 myclient = pymongo.MongoClient('mongodb://localhost:27017/')
#       4
# ----> 5 dblist = myclient.list_database_names()
#       6 # dblist = myclient.database_names()
#       7 if "runoobdb" in dblist:
#
# /home/tao/anaconda2/lib/python2.7/site-packages/pymongo/mongo_client.pyc in list_database_names(self, session)
#    1697         """
#    1698         return [doc["name"]
# -> 1699                 for doc in self.list_databases(session, nameOnly=True)]
#    1700
#    1701     def database_names(self, session=None):
#
# /home/tao/anaconda2/lib/python2.7/site-packages/pymongo/mongo_client.pyc in list_databases(self, session, **kwargs)
#    1678         cmd.update(kwargs)
#    1679         admin = self._database_default_options("admin")
# ...

# %%
import pymongo
import pandas as pd
 
 
def _connect_mongo(host, port, username, password, db,role):
 """ A util for making a connection to mongo. """
 if username and password:
  mongo_uri = "mongodb://%s:%s@%s:%s/%s" % (username, password, host, port, role)
  conn = pymongo.MongoClient(mongo_uri)
 else:
  conn = pymongo.MongoClient(host, port)
 
 return conn[db]
 
 
def read_mongo(role,db, collection, query={}, host='test43', port=27017, username=None, password=None, no_id=True):
 """ Read from Mongo and Store into DataFrame. """
 
 # Connect to MongoDB
 db = _connect_mongo(host=host, port=port, username=username, password=password, db=db,role=role)
 
 # Make a query to the specific DB and Collection
 cursor = db[collection].find(query).limit(10)
 
 # Expand the cursor and construct the DataFrame
 df = pd.DataFrame(list(cursor))
 df.to_csv("abc.csv", encoding="utf_8_sig") # 处理中文乱码问题
 
 if no_id:
  del df['_id']
 
 return df

# %%
read_mongo(role = 'admin',db='futureData', collection='IC1905', query={}, host='47.103.52.183', port=27017, username="admin", password="123456")
# Out:
#   ActionDay  AskPrice1      AskPrice2      AskPrice3      AskPrice4  \
# 0  20190507     4888.0  1.797693e+308  1.797693e+308  1.797693e+308
# 1  20190507     4892.4  1.797693e+308  1.797693e+308  1.797693e+308
# 2  20190507     4891.8  1.797693e+308  1.797693e+308  1.797693e+308
# 3  20190507     4887.6  1.797693e+308  1.797693e+308  1.797693e+308
# 4  20190507     4875.2  1.797693e+308  1.797693e+308  1.797693e+308
# 5  20190507     4876.0  1.797693e+308  1.797693e+308  1.797693e+308
# 6  20190507     4875.2  1.797693e+308  1.797693e+308  1.797693e+308
# 7  20190507     4872.0  1.797693e+308  1.797693e+308  1.797693e+308
# 8  20190507     4873.2  1.797693e+308  1.797693e+308  1.797693e+308
# 9  20190507     4871.0  1.797693e+308  1.797693e+308  1.797693e+308
#
#        AskPrice5  AskVolume1  AskVolume2  AskVolume3  AskVolume4  \
# 0  1.797693e+308         3.0         0.0         0.0         0.0
# 1  1.797693e+308        20.0         0.0         0.0         0.0
# ...
